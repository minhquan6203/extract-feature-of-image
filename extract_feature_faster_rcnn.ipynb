# %%
#/content/scene_graph_benchmark/scene_graph_benchmark/AttrRCNN.py

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/train
# !rm -rf /content/test

# %%
# !unzip /content/drive/MyDrive/VQA/ViVQA/images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/000000458918.jpg
#   inflating: test/000000280866.jpg
#   inflating: test/000000445774.jpg
#   inflating: test/000000391956.jpg
#   inflating: test/000000359354.jpg
#   inflating: test/000000491525.jpg
#   inflating: test/000000323264.jpg
#   inflating: test/000000108914.jpg
#   inflating: test/000000565572.jpg
#   inflating: test/000000243500.jpg
#   inflating: test/000000142534.jpg
#   inflating: test/000000549718.jpg
#   inflating: test/000000377339.jpg
#   inflating: test/000000053989.jpg
#   inflating: test/000000124764.jpg
#   inflating: test/000000074335.jpg
#   inflating: test/000000421488.jpg
#   inflating: test/000000562849.jpg
#   inflating: test/000000408815.jpg
#   inflating: test/000000542147.jpg
#   inflating: test/000000084670.jpg
#   inflating: test/000000048680.jpg
#   inflating: test/000000498460.jpg
#   inflating: test/000000568882.jpg
#   inflating: test/000000547099.jpg
# ...

# %%
import shutil
import os
source = "/content/test/"
destination = "/content/train"
files_list = os.listdir(source)
files_des=os.listdir(destination)
for files in files_list:
  for files_d in files_des:
    if files == files_d:
      os.remove(source+files)
    # else:
    #   shutil.move(source+files, destination)

# %%
import shutil
import os
source = "/content/test/"
destination = "/content/train"
files_list = os.listdir(source)
for files in files_list:
    shutil.move(source+files, destination)

# %%
# !rm -rf /content/test

# %%
# !git clone https://gitlab.com/meetshah1995/vqa-maskrcnn-benchmark.git
# %cd vqa-maskrcnn-benchmark
# Out:
# Cloning into 'vqa-maskrcnn-benchmark'...
# remote: Enumerating objects: 730, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 730 (delta 0), reused 0 (delta 0), pack-reused 729
# Receiving objects: 100% (730/730), 3.77 MiB | 33.82 MiB/s, done.
# Resolving deltas: 100% (391/391), done.
# /content/vqa-maskrcnn-benchmark
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/maskrcnn_benchmark
# copying maskrcnn_benchmark/__init__.py -> build/lib.linux-x86_64-3.7/maskrcnn_benchmark
# creating build/lib.linux-x86_64-3.7/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/model_zoo.py -> build/lib.linux-x86_64-3.7/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/logger.py -> build/lib.linux-x86_64-3.7/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/collect_env.py -> build/lib.linux-x86_64-3.7/maskrcnn_benchmark/utils
# ...

# %%
# !python setup.py build
# !python setup.py develop
# Out:
# running build
# running build_py
# copying maskrcnn_benchmark/utils/imports.py -> build/lib.linux-x86_64-3.7/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/layers/nms.py -> build/lib.linux-x86_64-3.7/maskrcnn_benchmark/layers
# running build_ext
# building 'maskrcnn_benchmark._C' extension
# Emitting ninja build file /content/vqa-maskrcnn-benchmark/build/temp.linux-x86_64-3.7/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ...

# %%
# !pip install wget
import wget
# %mkdir detectron_weights
# !wget -O detectron_weights/detectron_model.pth  https://dl.fbaipublicfiles.com/pythia/detectron_model/detectron_model.pth
# !wget -O detectron_weights/detectron_model.yaml  https://dl.fbaipublicfiles.com/pythia/detectron_model/detectron_model.yaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=bf480f728c79ad2754bd7c6212060d4e77158825c39e672a0b0c215a4525acc8
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...
# --2022-11-16 04:29:02--  https://dl.fbaipublicfiles.com/pythia/detectron_model/detectron_model.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 684079216 (652M) [application/octet-stream]
# Saving to: ‘detectron_weights/detectron_model.pth’
#
# detectron_weights/d 100%[===================>] 652.39M  45.2MB/s    in 15s
#
# ...

# %%
# !pip3 install yacs cityscapesscripts timm einops
# !pip3 install torch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2
# !pip3 install Ninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 473 kB 14.3 MB/s
# ...
#      |████████████████████████████████| 548 kB 34.6 MB/s
# ...
#      |████████████████████████████████| 41 kB 619 kB/s
# ...
#      |████████████████████████████████| 78 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 46 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 163 kB 61.6 MB/s
# ...
#      |████████████████████████████████| 86 kB 6.7 MB/s
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26339 sha256=6610b5c1da4262ddd9c23d28c40882228c4d736182d3c33eac99cc5e5b40eef2
#   Stored in directory: /root/.cache/pip/wheels/35/f3/15/01aa6571f0a72ee6ae7b827c1491c37a1f72d686fd22b43b0e
# Successfully built typing
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 776.8 MB 16 kB/s
# ...

# %%
# !python /content/vqa-maskrcnn-benchmark/extract_fast_rcnn.py
# Out:
# /content/vqa-maskrcnn-benchmark/maskrcnn_benchmark/structures/boxlist_ops.py:45: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   keep = ((ws >= min_size) & (hs >= min_size)).nonzero().squeeze(1)
# Traceback (most recent call last):
#   File "/content/vqa-maskrcnn-benchmark/extract_fast_rcnn.py", line 253, in <module>
#     feature_extractor.extract_features()
#   File "/content/vqa-maskrcnn-benchmark/extract_fast_rcnn.py", line 244, in extract_features
#     features, infos = self.get_detectron_features(chunk)
#   File "/content/vqa-maskrcnn-benchmark/extract_fast_rcnn.py", line 214, in get_detectron_features
#     self.args.confidence_threshold
#   File "/content/vqa-maskrcnn-benchmark/extract_fast_rcnn.py", line 167, in _process_feature_extraction
#     keep = nms(dets, cls_scores, 0.25)
# ...
