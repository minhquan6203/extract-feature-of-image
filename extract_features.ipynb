# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/UIT_SQUAD/Data/private_test/private-test-images.zip
# Out:
# Archive:  /content/drive/MyDrive/UIT_SQUAD/Data/private_test/private-test-images.zip
#    creating: private-test-images/
#   inflating: private-test-images/00000003605.jpg
#   inflating: private-test-images/00000000268.jpg
#   inflating: private-test-images/00000000407.jpg
#   inflating: private-test-images/00000003861.jpg
#   inflating: private-test-images/00000004150.jpg
#   inflating: private-test-images/00000004968.jpg
#   inflating: private-test-images/00000006113.jpg
#   inflating: private-test-images/00000007361.jpg
#   inflating: private-test-images/00000002575.jpg
#   inflating: private-test-images/00000005974.jpg
#   inflating: private-test-images/00000002696.jpg
#   inflating: private-test-images/00000001498.jpg
#   inflating: private-test-images/00000004333.jpg
#   inflating: private-test-images/00000003056.jpg
#   inflating: private-test-images/00000004915.jpg
#   inflating: private-test-images/00000011686.jpg
#   inflating: private-test-images/00000009851.jpg
# ...

# %%
# !git clone https://github.com/microsoft/scene_graph_benchmark.git
# Out:
# Cloning into 'scene_graph_benchmark'...
# remote: Enumerating objects: 795, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 795 (delta 96), reused 81 (delta 81), pack-reused 658
# Receiving objects: 100% (795/795), 21.22 MiB | 17.88 MiB/s, done.
# Resolving deltas: 100% (391/391), done.

# %%
# %cd /content/scene_graph_benchmark/
# Out:
# /content/scene_graph_benchmark

# %%
# !pip3 install yacs cityscapesscripts timm einops
# !pip3 install torch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 473 kB 36.1 MB/s
# ...
#      |████████████████████████████████| 548 kB 63.8 MB/s
# ...
#      |████████████████████████████████| 41 kB 518 kB/s
# ...
#      |████████████████████████████████| 46 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 78 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 163 kB 66.3 MB/s
# ...
#      |████████████████████████████████| 86 kB 6.9 MB/s
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26339 sha256=8ce28c9c079e03eb8b5e8acf2ef8d2f62191efaeaf423ec4ce880ce640a23f6f
#   Stored in directory: /root/.cache/pip/wheels/35/f3/15/01aa6571f0a72ee6ae7b827c1491c37a1f72d686fd22b43b0e
# Successfully built typing
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 776.8 MB 16 kB/s
# ...

# %%
# !python3 setup.py build develop
# Out:
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/scene_graph_benchmark
# copying scene_graph_benchmark/AttrRCNN.py -> build/lib.linux-x86_64-3.7/scene_graph_benchmark
# copying scene_graph_benchmark/scene_parser.py -> build/lib.linux-x86_64-3.7/scene_graph_benchmark
# copying scene_graph_benchmark/registry.py -> build/lib.linux-x86_64-3.7/scene_graph_benchmark
# copying scene_graph_benchmark/__init__.py -> build/lib.linux-x86_64-3.7/scene_graph_benchmark
# creating build/lib.linux-x86_64-3.7/maskrcnn_benchmark
# copying maskrcnn_benchmark/__init__.py -> build/lib.linux-x86_64-3.7/maskrcnn_benchmark
# creating build/lib.linux-x86_64-3.7/scene_graph_benchmark/attribute_head
# copying scene_graph_benchmark/attribute_head/inference.py -> build/lib.linux-x86_64-3.7/scene_graph_benchmark/attribute_head
# ...

# %%
# !wget https://penzhanwu2.blob.core.windows.net/sgg/sgg_benchmark/vinvl_model_zoo/vinvl_vg_x152c4.pth
# Out:
# --2022-11-11 03:45:37--  https://penzhanwu2.blob.core.windows.net/sgg/sgg_benchmark/vinvl_model_zoo/vinvl_vg_x152c4.pth
# Resolving penzhanwu2.blob.core.windows.net (penzhanwu2.blob.core.windows.net)... 20.60.153.33
# Connecting to penzhanwu2.blob.core.windows.net (penzhanwu2.blob.core.windows.net)|20.60.153.33|:443... connected.
# HTTP request sent, awaiting response... 404 The specified resource does not exist.
# 2022-11-11 03:45:37 ERROR 404: The specified resource does not exist..

# %%
# !wget https://biglmdiag.blob.core.windows.net/vinvl/model_ckpts/od_models/FourSets/model_final.pth
# Out:
# --2022-11-11 09:08:54--  https://biglmdiag.blob.core.windows.net/vinvl/model_ckpts/od_models/FourSets/model_final.pth
# Resolving biglmdiag.blob.core.windows.net (biglmdiag.blob.core.windows.net)... 52.240.48.36
# Connecting to biglmdiag.blob.core.windows.net (biglmdiag.blob.core.windows.net)|52.240.48.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1188767051 (1.1G) [application/octet-stream]
# Saving to: ‘model_final.pth’
#
# model_final.pth     100%[===================>]   1.11G  6.30MB/s    in 4m 30s
#
# 2022-11-11 09:13:25 (4.20 MB/s) - ‘model_final.pth’ saved [1188767051/1188767051]

# %%
# !python /content/scene_graph_benchmark/extract_features.py --config-file sgg_configs/vgattr/vinvl_x152c4.yaml \
                                                           TEST.IMS_PER_BATCH 1 \
                                                           MODEL.WEIGHT /content/scene_graph_benchmark/model_final.pth \
                                                           MODEL.ROI_HEADS.NMS_FILTER 1 \
                                                           MODEL.ROI_HEADS.SCORE_THRESH 0.2 \
                                                           DATA_DIR images \
                                                           TEST.IGNORE_BOX_REGRESSION False \
                                                           MODEL.ATTRIBUTE_ON False \
                                                           TEST.OUTPUT_FEATURE True
# Out:
# 2022-11-11 09:22:11,843 maskrcnn_benchmark INFO: Using 1 GPUs
# 2022-11-11 09:22:11,843 maskrcnn_benchmark INFO: DATALOADER:
#   ASPECT_RATIO_GROUPING: True
#   NUM_WORKERS: 0
#   SIZE_DIVISIBILITY: 0
# DATASETS:
#   FACTORY_TEST: ('VGTSVDataset',)
#   FACTORY_TRAIN: ('VGTSVDataset',)
#   LABELMAP_FILE: visualgenome/VG-SGG-dicts-vgoi6-clipped.json
#   TEST: ('visualgenome/test_vgoi6_clipped.yaml',)
#   TRAIN: ('visualgenome/train_vgoi6_clipped.yaml',)
# DATA_DIR: images
# DISTRIBUTED_BACKEND: gloo
# DTYPE: float32
# INPUT:
#   BRIGHTNESS: 0.0
#   CONTRAST: 0.0
#   HORIZONTAL_FLIP_PROB_TRAIN: 0.5
#   HUE: 0.0
#   MAX_SIZE_TEST: 1000
#   MAX_SIZE_TRAIN: 1333
#   MIN_SIZE_TEST: 600
#   MIN_SIZE_TRAIN: (800,)
#   PIXEL_MEAN: [103.53, 116.28, 123.675]
#   PIXEL_STD: [1.0, 1.0, 1.0]
#   SATURATION: 0.0
#   TO_BGR255: True
#   VERTICAL_FLIP_PROB_TRAIN: 0.0
# LOG_LOSS_PERIOD: 20
# MODEL:
#   ATTRIBUTE_ON: False
#   BACKBONE:
#     CONV_BODY: R-152-C4
#     FREEZE_CONV_BODY_AT: 2
# ...
